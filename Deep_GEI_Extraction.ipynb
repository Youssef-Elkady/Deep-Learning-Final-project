# %%
# !ln -s "/content/drive/MyDrive/gait" "/content/gait"

# %%
import torch
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

# %%
# !rm -r /content/Output

# %%
import torch
import cv2
import numpy as np
import torchvision.models.segmentation as segmentation_models
import torchvision
def mask_persons_only(frames, model):
    # Convert the frame to a tensor and normalize it
    preprocess = torchvision.transforms.Compose([
        torchvision.transforms.ToPILImage(),
        torchvision.transforms.ToTensor(),
        torchvision.transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225]),
    ])
    processed_images = []
    for frame in frames:
      input_tensor = preprocess(frame)
      processed_images.append(input_tensor)
    batch_tensor = torch.stack(processed_images)
    batch_tensor = batch_tensor.to(device)
      # Add batch dimension

    # Perform the forward pass to get the output
    with torch.no_grad():
        output = model(batch_tensor)['out']  # The output is a tensor with shape [21, H, W]

    # Get the segmentation map for the "person" class (class 15)
    person_class = 15
    person_masks = output.argmax(1) == person_class
    masked_frames = []
    for i in range(len(person_masks)):
              # Apply the mask to the frame to get the silhouette
              # Convert the mask to uint8
              person_mask = person_masks[i].byte().cpu().numpy()
              person_mask = cv2.resize(person_mask, (frames[i].shape[1], frames[i].shape[0]))
              person_mask = (person_mask * 255).astype(np.uint8)
              masked_frames.append(person_mask)


    return masked_frames

# %%
import cv2
import numpy as np
import tensorflow as tf
from tensorflow.keras.preprocessing import image
import numpy as np
import os
import torch
import torchvision.models.segmentation as segmentation_models
import imutils
model = segmentation_models.deeplabv3_resnet50(pretrained=True, progress=True, num_classes=21, aux_params=None)
model = model.to(device)
model.eval()
def get_human_silhouettes(video_path, output_dir, batch_size=10, padding=5, threshold=15):
    # Create output directory if it does not exist
    if not os.path.exists(output_dir):
        os.makedirs(output_dir)

    # Initialize video capture
    cap = cv2.VideoCapture(video_path)
    frame_count = 0
    batch_frames = []
    last_saved_frame = None
    silhouette_list = []

    while True:
        ret, frame = cap.read()
        if not ret:
            break

        # Convert frame to RGB and preprocess
        frame = frame[0: -100, :]
        frame = imutils.resize(frame, width=500)
        batch_frames.append(frame)
        frame_count += 1

        if len(batch_frames) == batch_size or not ret:
            # Perform segmentation on the batch
            predicted_masks = mask_persons_only(batch_frames, model)
            for i in range(len(batch_frames)):
                silhouette = predicted_masks[i]
                contours, _ = cv2.findContours(silhouette, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
                if len(contours) == 0:
                    continue  # No contours found

                # Find the largest contour
                largest_contour = max(contours, key=cv2.contourArea)
                x, y, w, h = cv2.boundingRect(largest_contour)
                side = max(w, h)
                sidePadding = (side - w) // 2
                topPadding = (side - h) // 2
                cropped = batch_frames[i][y - padding:y + h + padding, x - padding:x + w + padding]
                croppedSillh = silhouette[y - padding:y + h + padding, x - padding:x + w + padding]
                if cropped is None:
                  continue
                # Get contour
                try:
                  gr = cv2.cvtColor(cropped, cv2.COLOR_BGR2GRAY)
                except:
                  continue
                _, thresh1 = cv2.threshold(gr, 150, 255, cv2.THRESH_BINARY_INV)
                mergeThresh = cv2.bitwise_and(thresh1, croppedSillh)
                paddedFrame = cv2.copyMakeBorder(mergeThresh, topPadding, topPadding, sidePadding, sidePadding, cv2.BORDER_CONSTANT)

                # Resize to ensure same dimensions
                if last_saved_frame is not None:
                    paddedFrame = cv2.resize(paddedFrame, last_saved_frame.shape[::-1])

                # Save the silhouette frame to the output directory
                if last_saved_frame is None or np.mean(np.abs(paddedFrame.astype(np.float32) - last_saved_frame.astype(np.float32))) >= threshold:
                    last_saved_frame = paddedFrame
                    silhouette_list.append(paddedFrame)

            # Clear the batch lists
            batch_frames = []
            print(f"Processed {frame_count} frames, saved {len(silhouette_list)} frames")

    print(f"Total silhouettes saved: {len(silhouette_list)}")
    cap.release()

    # Compute average image
    if len(silhouette_list) > 0:
        avg_image = silhouette_list[0].astype(np.float32)
        for i in range(1, len(silhouette_list)):
            alpha = 1.0 / (i + 1)
            beta = 1.0 - alpha
            avg_image = cv2.addWeighted(silhouette_list[i].astype(np.float32), alpha, avg_image, beta, 0.0)

        silhouette_path = os.path.join(output_dir, f'silhouette.png')
        cv2.imwrite(silhouette_path, avg_image.astype(np.uint8))
        print(f"Saved final silhouette image to {silhouette_path}")
    else:
        print("No silhouettes to save")
# Out:
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=DeepLabV3_ResNet50_Weights.COCO_WITH_VOC_LABELS_V1`. You can also use `weights=DeepLabV3_ResNet50_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)

# %%
import os
import re

# Define the paths and match string
path = "/content/gait"
output_dir = '/content/gait/Output'
match_string = ".*front\\.mov$"

# Iterate through each person in the directory
for person in os.listdir(path):
    person_path = os.path.join(path, person)

    # Ensure we're only looking at directories
    if os.path.isdir(person_path):
        for file_ in os.listdir(person_path):
            # Check if the file matches the specified pattern
            if re.match(match_string, file_, re.IGNORECASE):
                input_file_path = os.path.join(person_path, file_)

                # Create the output directory for this person if it doesn't exist
                person_output_dir = os.path.join(output_dir, person)
                if not os.path.exists(person_output_dir):
                    os.makedirs(person_output_dir)

                # Call the get_human_silhouettes function
                get_human_silhouettes(input_file_path, person_output_dir)
                print(f"Processed {input_file_path} and saved results to {person_output_dir}")
# Out:
# Total silhouettes saved: 0
# No silhouettes to save
# Processed /content/gait/sub42/adelka_m_1_front.MOV and saved results to /content/gait/Output/sub42
# Total silhouettes saved: 0
# No silhouettes to save
# Processed /content/gait/sub29/ahmedma_m_1_front.MOV and saved results to /content/gait/Output/sub29
# Processed 10 frames, saved 1 frames
# Processed 20 frames, saved 1 frames
# Processed 30 frames, saved 3 frames
# Processed 40 frames, saved 7 frames
# Processed 50 frames, saved 11 frames
# Processed 60 frames, saved 16 frames
# Processed 70 frames, saved 16 frames
# Processed 80 frames, saved 17 frames
# Processed 90 frames, saved 19 frames
# Processed 100 frames, saved 22 frames
# Processed 110 frames, saved 25 frames
# Processed 120 frames, saved 25 frames
# Processed 130 frames, saved 25 frames
# Processed 140 frames, saved 25 frames
# Processed 150 frames, saved 25 frames
# Processed 160 frames, saved 25 frames
# Processed 170 frames, saved 25 frames
# Processed 180 frames, saved 25 frames
# Processed 190 frames, saved 25 frames
# Processed 200 frames, saved 25 frames
# Processed 210 frames, saved 25 frames
# Processed 220 frames, saved 25 frames
# Processed 230 frames, saved 25 frames
# Processed 240 frames, saved 27 frames
# Processed 250 frames, saved 32 frames
# Processed 260 frames, saved 36 frames
# Processed 270 frames, saved 39 frames
# Processed 280 frames, saved 43 frames
# Processed 290 frames, saved 47 frames
# Processed 300 frames, saved 51 frames
# Processed 310 frames, saved 54 frames
# Processed 320 frames, saved 57 frames
# Processed 330 frames, saved 61 frames
# Processed 340 frames, saved 64 frames
# Processed 350 frames, saved 69 frames
# Processed 360 frames, saved 72 frames
# Processed 370 frames, saved 73 frames
# Processed 380 frames, saved 73 frames
# Processed 390 frames, saved 73 frames
# Processed 400 frames, saved 73 frames
# Processed 410 frames, saved 73 frames
# Processed 420 frames, saved 73 frames
# Processed 430 frames, saved 73 frames
# Processed 440 frames, saved 74 frames
# Processed 450 frames, saved 77 frames
# Processed 460 frames, saved 81 frames
# Processed 470 frames, saved 84 frames
# Processed 480 frames, saved 87 frames
# Processed 490 frames, saved 91 frames
# Processed 500 frames, saved 95 frames
# Processed 510 frames, saved 98 frames
# Processed 520 frames, saved 102 frames
# Processed 530 frames, saved 106 frames
# Processed 540 frames, saved 109 frames
# Processed 550 frames, saved 113 frames
# Processed 560 frames, saved 115 frames
# Processed 570 frames, saved 120 frames
# Processed 580 frames, saved 120 frames
# Processed 590 frames, saved 120 frames
# Processed 600 frames, saved 120 frames
# Processed 610 frames, saved 120 frames
# Processed 620 frames, saved 120 frames
# Processed 630 frames, saved 120 frames
# Processed 640 frames, saved 120 frames
# Processed 650 frames, saved 120 frames
# Processed 660 frames, saved 120 frames
# Processed 670 frames, saved 120 frames
# Processed 680 frames, saved 120 frames
# Processed 690 frames, saved 123 frames
# Processed 700 frames, saved 127 frames
# Processed 710 frames, saved 131 frames
# Processed 720 frames, saved 135 frames
# Processed 730 frames, saved 139 frames
# Processed 740 frames, saved 143 frames
# Processed 750 frames, saved 147 frames
# Processed 760 frames, saved 152 frames
# Processed 770 frames, saved 155 frames
# Processed 780 frames, saved 159 frames
# Processed 790 frames, saved 162 frames
# Processed 800 frames, saved 166 frames
# Processed 810 frames, saved 169 frames
# Processed 820 frames, saved 170 frames
# Processed 830 frames, saved 170 frames
# Processed 840 frames, saved 170 frames
# Processed 850 frames, saved 170 frames
# Processed 860 frames, saved 170 frames
# Processed 870 frames, saved 170 frames
# Processed 880 frames, saved 170 frames
# Processed 890 frames, saved 171 frames
# Processed 900 frames, saved 175 frames
# Processed 910 frames, saved 179 frames
# Processed 920 frames, saved 183 frames
# Processed 930 frames, saved 186 frames
# Processed 940 frames, saved 190 frames
# Processed 950 frames, saved 193 frames
# Processed 960 frames, saved 197 frames
# Processed 970 frames, saved 201 frames
# Processed 980 frames, saved 205 frames
# Processed 990 frames, saved 209 frames
# Processed 1000 frames, saved 212 frames
# Processed 1010 frames, saved 215 frames
# Processed 1020 frames, saved 220 frames
# Processed 1030 frames, saved 220 frames
# Processed 1040 frames, saved 220 frames
# Processed 1050 frames, saved 220 frames
# Processed 1060 frames, saved 220 frames
# Processed 1070 frames, saved 220 frames
# Processed 1080 frames, saved 220 frames
# Processed 1090 frames, saved 220 frames
# Processed 1100 frames, saved 220 frames
# Processed 1110 frames, saved 220 frames
# Processed 1120 frames, saved 220 frames
# Processed 1130 frames, saved 220 frames
# Processed 1140 frames, saved 223 frames
# Processed 1150 frames, saved 226 frames
# Processed 1160 frames, saved 230 frames
# Processed 1170 frames, saved 234 frames
# Processed 1180 frames, saved 237 frames
# Processed 1190 frames, saved 241 frames
# Processed 1200 frames, saved 245 frames
# Processed 1210 frames, saved 249 frames
# Processed 1220 frames, saved 253 frames
# Processed 1230 frames, saved 257 frames
# Processed 1240 frames, saved 261 frames
# Processed 1250 frames, saved 264 frames
# Processed 1260 frames, saved 265 frames
# Processed 1270 frames, saved 265 frames
# Processed 1280 frames, saved 265 frames
# Processed 1290 frames, saved 265 frames
# Processed 1300 frames, saved 265 frames
# Processed 1310 frames, saved 265 frames
# Processed 1320 frames, saved 265 frames
# Processed 1330 frames, saved 265 frames
# Processed 1340 frames, saved 266 frames
# Processed 1350 frames, saved 269 frames
# Processed 1360 frames, saved 272 frames
# Processed 1370 frames, saved 276 frames
# Processed 1380 frames, saved 280 frames
# Processed 1390 frames, saved 284 frames
# Processed 1400 frames, saved 288 frames
# Processed 1410 frames, saved 291 frames
# Processed 1420 frames, saved 296 frames
# Processed 1430 frames, saved 301 frames
# Processed 1440 frames, saved 305 frames
# Processed 1450 frames, saved 308 frames
# Processed 1460 frames, saved 311 frames
# Processed 1470 frames, saved 315 frames
# Processed 1480 frames, saved 315 frames
# Processed 1490 frames, saved 315 frames
# Processed 1500 frames, saved 315 frames
# Processed 1510 frames, saved 315 frames
# Processed 1520 frames, saved 315 frames
# Processed 1530 frames, saved 315 frames
# Processed 1540 frames, saved 315 frames
# Processed 1550 frames, saved 315 frames
# Processed 1560 frames, saved 315 frames
# Total silhouettes saved: 315
# Saved final silhouette image to /content/gait/Output/sub43/silhouette.png
# Processed /content/gait/sub43/yassercollect_m_1_front.MOV and saved results to /content/gait/Output/sub43
# Processed 10 frames, saved 1 frames
# Processed 20 frames, saved 1 frames
# Processed 30 frames, saved 1 frames
# Processed 40 frames, saved 1 frames
# Processed 50 frames, saved 1 frames
# Processed 60 frames, saved 1 frames
# Processed 70 frames, saved 1 frames
# Processed 80 frames, saved 5 frames
# Processed 90 frames, saved 8 frames
# Processed 100 frames, saved 12 frames
# Processed 110 frames, saved 15 frames
# Processed 120 frames, saved 16 frames
# Processed 130 frames, saved 19 frames
# Processed 140 frames, saved 23 frames
# Processed 150 frames, saved 23 frames
# Processed 160 frames, saved 23 frames
# Processed 170 frames, saved 23 frames
# Processed 180 frames, saved 23 frames
# Processed 190 frames, saved 23 frames
# Processed 200 frames, saved 23 frames
# Processed 210 frames, saved 23 frames
# Processed 220 frames, saved 23 frames
# Processed 230 frames, saved 23 frames
# Processed 240 frames, saved 23 frames
# Processed 250 frames, saved 23 frames
# Processed 260 frames, saved 25 frames
# Processed 270 frames, saved 28 frames
# Processed 280 frames, saved 32 frames
# Processed 290 frames, saved 36 frames
# Processed 300 frames, saved 40 frames
# Processed 310 frames, saved 43 frames
# Processed 320 frames, saved 47 frames
# Processed 330 frames, saved 51 frames
# Processed 340 frames, saved 55 frames
# Processed 350 frames, saved 58 frames
# Processed 360 frames, saved 62 frames
# Processed 370 frames, saved 65 frames
# Processed 380 frames, saved 68 frames
# Processed 390 frames, saved 69 frames
# Processed 400 frames, saved 69 frames
# Processed 410 frames, saved 69 frames
# Processed 420 frames, saved 69 frames
# Processed 430 frames, saved 70 frames
# Processed 440 frames, saved 73 frames
# Processed 450 frames, saved 77 frames
# Processed 460 frames, saved 80 frames
# Processed 470 frames, saved 83 frames
# Processed 480 frames, saved 88 frames
# Processed 490 frames, saved 91 frames
# Processed 500 frames, saved 94 frames
# Processed 510 frames, saved 98 frames
# Processed 520 frames, saved 102 frames
# Processed 530 frames, saved 106 frames
# Processed 540 frames, saved 109 frames
# Processed 550 frames, saved 113 frames
# Processed 560 frames, saved 117 frames
# Processed 570 frames, saved 117 frames
# Processed 580 frames, saved 117 frames
# Processed 590 frames, saved 117 frames
# Processed 600 frames, saved 117 frames
# Processed 610 frames, saved 117 frames
# Processed 620 frames, saved 117 frames
# Processed 630 frames, saved 117 frames
# Processed 640 frames, saved 117 frames
# Processed 650 frames, saved 117 frames
# Processed 660 frames, saved 117 frames
# Processed 670 frames, saved 120 frames
# Processed 680 frames, saved 124 frames
# Processed 690 frames, saved 127 frames
# Processed 700 frames, saved 131 frames
# Processed 710 frames, saved 133 frames
# Processed 720 frames, saved 137 frames
# Processed 730 frames, saved 140 frames
# Processed 740 frames, saved 144 frames
# Processed 750 frames, saved 148 frames
# Processed 760 frames, saved 151 frames
# Processed 770 frames, saved 155 frames
# Processed 780 frames, saved 159 frames
# Processed 790 frames, saved 163 frames
# Processed 800 frames, saved 166 frames
# Processed 810 frames, saved 166 frames
# Processed 820 frames, saved 166 frames
# Processed 830 frames, saved 166 frames
# Processed 840 frames, saved 166 frames
# Processed 850 frames, saved 166 frames
# Processed 860 frames, saved 166 frames
# Processed 870 frames, saved 170 frames
# Processed 880 frames, saved 173 frames
# Processed 890 frames, saved 177 frames
# Processed 900 frames, saved 181 frames
# Processed 910 frames, saved 185 frames
# Processed 920 frames, saved 188 frames
# Processed 930 frames, saved 192 frames
# Processed 940 frames, saved 196 frames
# Processed 950 frames, saved 199 frames
# Processed 960 frames, saved 202 frames
# Processed 970 frames, saved 205 frames
# Processed 980 frames, saved 208 frames
# Processed 990 frames, saved 212 frames
# Processed 1000 frames, saved 214 frames
# Processed 1010 frames, saved 214 frames
# Processed 1020 frames, saved 214 frames
# Processed 1030 frames, saved 214 frames
# Processed 1040 frames, saved 214 frames
# Processed 1050 frames, saved 214 frames
# Processed 1060 frames, saved 214 frames
# Processed 1070 frames, saved 214 frames
# Processed 1080 frames, saved 214 frames
# Processed 1090 frames, saved 214 frames
# Processed 1100 frames, saved 214 frames
# Processed 1110 frames, saved 216 frames
# Processed 1120 frames, saved 219 frames
# Processed 1130 frames, saved 223 frames
# Processed 1140 frames, saved 227 frames
# Processed 1150 frames, saved 231 frames
# Processed 1160 frames, saved 235 frames
# Processed 1170 frames, saved 238 frames
# Processed 1180 frames, saved 241 frames
# Processed 1190 frames, saved 244 frames
# Processed 1200 frames, saved 248 frames
# Processed 1210 frames, saved 251 frames
# Processed 1220 frames, saved 255 frames
# Processed 1230 frames, saved 259 frames
# Processed 1240 frames, saved 261 frames
# Processed 1250 frames, saved 262 frames
# Processed 1260 frames, saved 262 frames
# Processed 1270 frames, saved 262 frames
# Processed 1280 frames, saved 262 frames
# Processed 1290 frames, saved 262 frames
# Processed 1300 frames, saved 262 frames
# Processed 1310 frames, saved 264 frames
# Processed 1320 frames, saved 266 frames
# Processed 1330 frames, saved 271 frames
# Processed 1340 frames, saved 275 frames
# Processed 1350 frames, saved 278 frames
# Processed 1360 frames, saved 281 frames
# Processed 1370 frames, saved 285 frames
# Processed 1380 frames, saved 288 frames
# Processed 1390 frames, saved 291 frames
# Processed 1400 frames, saved 295 frames
# Processed 1410 frames, saved 299 frames
# Processed 1420 frames, saved 302 frames
# Processed 1430 frames, saved 305 frames
# Processed 1440 frames, saved 309 frames
# Processed 1450 frames, saved 309 frames
# Processed 1460 frames, saved 309 frames
# Processed 1470 frames, saved 309 frames
# Processed 1480 frames, saved 309 frames
# Processed 1490 frames, saved 309 frames
# Processed 1500 frames, saved 309 frames
# Processed 1510 frames, saved 309 frames
# Processed 1520 frames, saved 309 frames
# Processed 1530 frames, saved 309 frames
# Processed 1540 frames, saved 309 frames
# Total silhouettes saved: 309
# Saved final silhouette image to /content/gait/Output/sub17/silhouette.png
# Processed /content/gait/sub17/sharsharj_m_1_front.MOV and saved results to /content/gait/Output/sub17
# Total silhouettes saved: 0
# No silhouettes to save
# Processed /content/gait/sub32/mohamedsla_m_1_front.MOV and saved results to /content/gait/Output/sub32
# Processed 10 frames, saved 1 frames
# Processed 20 frames, saved 1 frames
# Processed 30 frames, saved 1 frames
# Processed 40 frames, saved 1 frames
# Processed 50 frames, saved 1 frames
# Processed 60 frames, saved 1 frames
# Processed 70 frames, saved 1 frames
# Processed 80 frames, saved 1 frames
# Processed 90 frames, saved 1 frames
# Processed 100 frames, saved 1 frames
# Processed 110 frames, saved 1 frames
# Processed 120 frames, saved 8 frames
# Processed 130 frames, saved 12 frames
# Processed 140 frames, saved 19 frames
# Processed 150 frames, saved 22 frames
# Processed 160 frames, saved 22 frames
# Processed 170 frames, saved 22 frames
# Processed 180 frames, saved 22 frames
# Processed 190 frames, saved 24 frames
# Processed 200 frames, saved 32 frames
# Processed 210 frames, saved 36 frames
# Processed 220 frames, saved 41 frames
# Processed 230 frames, saved 43 frames
# Processed 240 frames, saved 43 frames
# Processed 250 frames, saved 43 frames
# Processed 260 frames, saved 43 frames
# Processed 270 frames, saved 43 frames
# Processed 280 frames, saved 43 frames
# Processed 290 frames, saved 43 frames
# Processed 300 frames, saved 43 frames
# Processed 310 frames, saved 44 frames
# Processed 320 frames, saved 44 frames
# Processed 330 frames, saved 44 frames
# Processed 340 frames, saved 44 frames
# Processed 350 frames, saved 45 frames
# Processed 360 frames, saved 46 frames
# Processed 370 frames, saved 47 frames
# Processed 380 frames, saved 48 frames
# Processed 390 frames, saved 49 frames
# Processed 400 frames, saved 53 frames
# Processed 410 frames, saved 57 frames
# Processed 420 frames, saved 57 frames
# Processed 430 frames, saved 57 frames
# Processed 440 frames, saved 57 frames
# Processed 450 frames, saved 57 frames
# Processed 460 frames, saved 57 frames
# Processed 470 frames, saved 57 frames
# Processed 480 frames, saved 57 frames
# Processed 490 frames, saved 57 frames
# Processed 500 frames, saved 57 frames
# Processed 510 frames, saved 57 frames
# Processed 520 frames, saved 57 frames
# Processed 530 frames, saved 57 frames
# Processed 540 frames, saved 62 frames
# Processed 550 frames, saved 67 frames
# Processed 560 frames, saved 71 frames
# Processed 570 frames, saved 75 frames
# Processed 580 frames, saved 79 frames
# Processed 590 frames, saved 83 frames
# Processed 600 frames, saved 88 frames
# Processed 610 frames, saved 92 frames
# Processed 620 frames, saved 96 frames
# Processed 630 frames, saved 100 frames
# Processed 640 frames, saved 104 frames
# Processed 650 frames, saved 105 frames
# Processed 660 frames, saved 105 frames
# Processed 670 frames, saved 105 frames
# Processed 680 frames, saved 105 frames
# Processed 690 frames, saved 106 frames
# Processed 700 frames, saved 110 frames
# Processed 710 frames, saved 114 frames
# Processed 720 frames, saved 119 frames
# Processed 730 frames, saved 123 frames
# Processed 740 frames, saved 128 frames
# Processed 750 frames, saved 133 frames
# Processed 760 frames, saved 137 frames
# Processed 770 frames, saved 142 frames
# Processed 780 frames, saved 146 frames
# Processed 790 frames, saved 151 frames
# Processed 800 frames, saved 152 frames
# Processed 810 frames, saved 152 frames
# Processed 820 frames, saved 152 frames
# Processed 830 frames, saved 152 frames
# Processed 840 frames, saved 152 frames
# Processed 850 frames, saved 152 frames
# Processed 860 frames, saved 152 frames
# Processed 870 frames, saved 152 frames
# Processed 880 frames, saved 152 frames
# Processed 890 frames, saved 156 frames
# Processed 900 frames, saved 162 frames
# Processed 910 frames, saved 165 frames
# Processed 920 frames, saved 169 frames
# Processed 930 frames, saved 173 frames
# Processed 940 frames, saved 177 frames
# Processed 950 frames, saved 183 frames
# Processed 960 frames, saved 187 frames
# Processed 970 frames, saved 191 frames
# Processed 980 frames, saved 195 frames
# Processed 990 frames, saved 196 frames
# Processed 1000 frames, saved 196 frames
# Processed 1010 frames, saved 196 frames
# Processed 1020 frames, saved 196 frames
# Processed 1030 frames, saved 198 frames
# Processed 1040 frames, saved 201 frames
# Processed 1050 frames, saved 205 frames
# Processed 1060 frames, saved 210 frames
# Processed 1070 frames, saved 215 frames
# Processed 1080 frames, saved 219 frames
# Processed 1090 frames, saved 225 frames
# Processed 1100 frames, saved 229 frames
# Processed 1110 frames, saved 234 frames
# Processed 1120 frames, saved 239 frames
# Processed 1130 frames, saved 243 frames
# Processed 1140 frames, saved 243 frames
# Processed 1150 frames, saved 243 frames
# Processed 1160 frames, saved 243 frames
# Processed 1170 frames, saved 243 frames
# Processed 1180 frames, saved 243 frames
# Processed 1190 frames, saved 243 frames
# Processed 1200 frames, saved 243 frames
# Processed 1210 frames, saved 243 frames
# Processed 1220 frames, saved 247 frames
# Processed 1230 frames, saved 252 frames
# Processed 1240 frames, saved 257 frames
# Processed 1250 frames, saved 261 frames
# Processed 1260 frames, saved 265 frames
# Processed 1270 frames, saved 270 frames
# Processed 1280 frames, saved 275 frames
# Processed 1290 frames, saved 279 frames
# Processed 1300 frames, saved 284 frames
# Processed 1310 frames, saved 288 frames
# Processed 1320 frames, saved 289 frames
# Processed 1330 frames, saved 289 frames
# Processed 1340 frames, saved 289 frames
# Processed 1350 frames, saved 289 frames
# Processed 1360 frames, saved 289 frames
# Processed 1370 frames, saved 291 frames
# Processed 1380 frames, saved 294 frames
# Processed 1390 frames, saved 298 frames
# Processed 1400 frames, saved 301 frames
# Processed 1410 frames, saved 306 frames
# Processed 1420 frames, saved 310 frames
# Processed 1430 frames, saved 315 frames
# Processed 1440 frames, saved 320 frames
# Processed 1450 frames, saved 324 frames
# Processed 1460 frames, saved 329 frames
# Processed 1470 frames, saved 332 frames
# Processed 1480 frames, saved 335 frames
# Processed 1490 frames, saved 335 frames
# Processed 1500 frames, saved 335 frames
# Processed 1510 frames, saved 335 frames
# Processed 1520 frames, saved 335 frames
# Processed 1530 frames, saved 335 frames
# Processed 1540 frames, saved 335 frames
# Processed 1550 frames, saved 335 frames
# Processed 1560 frames, saved 335 frames
# Total silhouettes saved: 335
# Saved final silhouette image to /content/gait/Output/sub12/silhouette.png
# Processed /content/gait/sub12/ahmedt_m_1_front.MOV and saved results to /content/gait/Output/sub12
# Total silhouettes saved: 0
# No silhouettes to save
# Processed /content/gait/sub40/youssefham_m_1_front.MOV and saved results to /content/gait/Output/sub40
# Processed 10 frames, saved 1 frames
# Processed 20 frames, saved 1 frames
# Processed 30 frames, saved 1 frames
# Processed 40 frames, saved 1 frames
# Processed 50 frames, saved 1 frames
# Processed 60 frames, saved 1 frames
# Processed 70 frames, saved 6 frames
# Processed 80 frames, saved 10 frames
# Processed 90 frames, saved 16 frames
# Processed 100 frames, saved 17 frames
# Processed 110 frames, saved 18 frames
# Processed 120 frames, saved 20 frames
# Processed 130 frames, saved 24 frames
# Processed 140 frames, saved 26 frames
# Processed 150 frames, saved 26 frames
# Processed 160 frames, saved 26 frames
# Processed 170 frames, saved 26 frames
# Processed 180 frames, saved 26 frames
# Processed 190 frames, saved 26 frames
# Processed 200 frames, saved 26 frames
# Processed 210 frames, saved 26 frames
# Processed 220 frames, saved 26 frames
# Processed 230 frames, saved 26 frames
# Processed 240 frames, saved 28 frames
# Processed 250 frames, saved 33 frames
# Processed 260 frames, saved 37 frames
# Processed 270 frames, saved 40 frames
# Processed 280 frames, saved 43 frames
# Processed 290 frames, saved 46 frames
# Processed 300 frames, saved 50 frames
# Processed 310 frames, saved 54 frames
# Processed 320 frames, saved 57 frames
# Processed 330 frames, saved 60 frames
# Processed 340 frames, saved 64 frames
# Processed 350 frames, saved 67 frames
# Processed 360 frames, saved 69 frames
# Processed 370 frames, saved 69 frames
# Processed 380 frames, saved 69 frames
# Processed 390 frames, saved 69 frames
# Processed 400 frames, saved 69 frames
# Processed 410 frames, saved 69 frames
# Processed 420 frames, saved 69 frames
# Processed 430 frames, saved 72 frames
# Processed 440 frames, saved 76 frames
# Processed 450 frames, saved 80 frames
# Processed 460 frames, saved 85 frames
# Processed 470 frames, saved 90 frames
# Processed 480 frames, saved 93 frames
# Processed 490 frames, saved 98 frames
# Processed 500 frames, saved 103 frames
# Processed 510 frames, saved 106 frames
# Processed 520 frames, saved 111 frames
# Processed 530 frames, saved 114 frames
# Processed 540 frames, saved 116 frames
# Processed 550 frames, saved 116 frames
# Processed 560 frames, saved 116 frames
# Processed 570 frames, saved 116 frames
# Processed 580 frames, saved 116 frames
# Processed 590 frames, saved 116 frames
# Processed 600 frames, saved 116 frames
# Processed 610 frames, saved 116 frames
# Processed 620 frames, saved 116 frames
# Processed 630 frames, saved 116 frames
# Processed 640 frames, saved 118 frames
# Processed 650 frames, saved 122 frames
# Processed 660 frames, saved 126 frames
# Processed 670 frames, saved 130 frames
# Processed 680 frames, saved 134 frames
# Processed 690 frames, saved 137 frames
# Processed 700 frames, saved 141 frames
# Processed 710 frames, saved 146 frames
# Processed 720 frames, saved 150 frames
# Processed 730 frames, saved 154 frames
# Processed 740 frames, saved 158 frames
# Processed 750 frames, saved 161 frames
# Processed 760 frames, saved 161 frames
# Processed 770 frames, saved 161 frames
# Processed 780 frames, saved 161 frames
# Processed 790 frames, saved 161 frames
# Processed 800 frames, saved 161 frames
# Processed 810 frames, saved 163 frames
# Processed 820 frames, saved 167 frames
# Processed 830 frames, saved 172 frames
# Processed 840 frames, saved 176 frames
# Processed 850 frames, saved 180 frames
# Processed 860 frames, saved 184 frames
# Processed 870 frames, saved 188 frames
# Processed 880 frames, saved 192 frames
# Processed 890 frames, saved 196 frames
# Processed 900 frames, saved 201 frames
# Processed 910 frames, saved 204 frames
# Processed 920 frames, saved 209 frames
# Processed 930 frames, saved 210 frames
# Processed 940 frames, saved 210 frames
# Processed 950 frames, saved 210 frames
# Processed 960 frames, saved 210 frames
# Processed 970 frames, saved 210 frames
# Processed 980 frames, saved 210 frames
# Processed 990 frames, saved 210 frames
# Processed 1000 frames, saved 210 frames
# Processed 1010 frames, saved 210 frames
# Processed 1020 frames, saved 210 frames
# Processed 1030 frames, saved 215 frames
# Processed 1040 frames, saved 221 frames
# Processed 1050 frames, saved 223 frames
# Processed 1060 frames, saved 227 frames
# Processed 1070 frames, saved 230 frames
# Processed 1080 frames, saved 236 frames
# Processed 1090 frames, saved 239 frames
# Processed 1100 frames, saved 243 frames
# Processed 1110 frames, saved 247 frames
# Processed 1120 frames, saved 251 frames
# Processed 1130 frames, saved 254 frames
# Processed 1140 frames, saved 257 frames
# Processed 1150 frames, saved 258 frames
# Processed 1160 frames, saved 258 frames
# Processed 1170 frames, saved 258 frames
# Processed 1180 frames, saved 258 frames
# Processed 1190 frames, saved 258 frames
# Processed 1200 frames, saved 258 frames
# Processed 1210 frames, saved 258 frames
# Processed 1220 frames, saved 259 frames
# Processed 1230 frames, saved 263 frames
# Processed 1240 frames, saved 268 frames
# Processed 1250 frames, saved 272 frames
# Processed 1260 frames, saved 276 frames
# Processed 1270 frames, saved 280 frames
# Processed 1280 frames, saved 284 frames
# Processed 1290 frames, saved 287 frames
# Processed 1300 frames, saved 291 frames
# Processed 1310 frames, saved 295 frames
# Processed 1320 frames, saved 300 frames
# Processed 1330 frames, saved 303 frames
# Processed 1340 frames, saved 306 frames
# Processed 1350 frames, saved 308 frames
# Processed 1360 frames, saved 308 frames
# Processed 1370 frames, saved 308 frames
# Processed 1380 frames, saved 308 frames
# Processed 1390 frames, saved 308 frames
# Processed 1400 frames, saved 308 frames
# Processed 1410 frames, saved 308 frames
# Processed 1420 frames, saved 308 frames
# Processed 1430 frames, saved 308 frames
# Processed 1440 frames, saved 308 frames
# Processed 1450 frames, saved 308 frames
# Processed 1460 frames, saved 308 frames
# Total silhouettes saved: 308
# Saved final silhouette image to /content/gait/Output/sub36/silhouette.png
# Processed /content/gait/sub36/menatullah_f_1_front.MOV and saved results to /content/gait/Output/sub36
# Processed 10 frames, saved 1 frames
# Processed 20 frames, saved 1 frames
# Processed 30 frames, saved 1 frames
# Processed 40 frames, saved 1 frames
# Processed 50 frames, saved 1 frames
# Processed 60 frames, saved 1 frames
# Processed 70 frames, saved 1 frames
# Processed 80 frames, saved 1 frames
# Processed 90 frames, saved 1 frames
# Processed 100 frames, saved 1 frames
# Processed 110 frames, saved 1 frames
# Processed 120 frames, saved 1 frames
# Processed 130 frames, saved 1 frames
# Processed 140 frames, saved 1 frames
# Processed 150 frames, saved 1 frames
# Processed 160 frames, saved 1 frames
# Processed 170 frames, saved 1 frames
# Processed 180 frames, saved 2 frames
# Processed 190 frames, saved 6 frames
# Processed 200 frames, saved 8 frames
# Processed 210 frames, saved 10 frames
# Processed 220 frames, saved 14 frames
# Processed 230 frames, saved 16 frames
# Processed 240 frames, saved 17 frames
# Processed 250 frames, saved 17 frames
# Processed 260 frames, saved 18 frames
# Processed 270 frames, saved 19 frames
# Processed 280 frames, saved 20 frames
# Processed 290 frames, saved 23 frames
# Processed 300 frames, saved 25 frames
# Processed 310 frames, saved 25 frames
# Processed 320 frames, saved 25 frames
# Processed 330 frames, saved 25 frames
# Processed 340 frames, saved 25 frames
# Processed 350 frames, saved 25 frames
# Processed 360 frames, saved 25 frames
# Processed 370 frames, saved 25 frames
# Processed 380 frames, saved 25 frames
# Processed 390 frames, saved 25 frames
# Processed 400 frames, saved 25 frames
# Processed 410 frames, saved 25 frames
# Processed 420 frames, saved 25 frames
# Processed 430 frames, saved 25 frames
# Processed 440 frames, saved 25 frames
# Processed 450 frames, saved 28 frames
# Processed 460 frames, saved 31 frames
# Processed 470 frames, saved 33 frames
# Processed 480 frames, saved 37 frames
# Processed 490 frames, saved 41 frames
# Processed 500 frames, saved 44 frames
# Processed 510 frames, saved 47 frames
# Processed 520 frames, saved 51 frames
# Processed 530 frames, saved 54 frames
# Processed 540 frames, saved 57 frames
# Processed 550 frames, saved 60 frames
# Processed 560 frames, saved 64 frames
# Processed 570 frames, saved 68 frames
# Processed 580 frames, saved 70 frames
# Processed 590 frames, saved 70 frames
# Processed 600 frames, saved 70 frames
# Processed 610 frames, saved 70 frames
# Processed 620 frames, saved 70 frames
# Processed 630 frames, saved 70 frames
# Processed 640 frames, saved 70 frames
# Processed 650 frames, saved 70 frames
# Processed 660 frames, saved 71 frames
# Processed 670 frames, saved 73 frames
# Processed 680 frames, saved 76 frames
# Processed 690 frames, saved 80 frames
# Processed 700 frames, saved 84 frames
# Processed 710 frames, saved 87 frames
# Processed 720 frames, saved 91 frames
# Processed 730 frames, saved 94 frames
# Processed 740 frames, saved 97 frames
# Processed 750 frames, saved 98 frames
# Processed 760 frames, saved 100 frames
# Processed 770 frames, saved 105 frames
# Processed 780 frames, saved 108 frames
# Processed 790 frames, saved 112 frames
# Processed 800 frames, saved 114 frames
# Processed 810 frames, saved 115 frames
# Processed 820 frames, saved 115 frames
# Processed 830 frames, saved 115 frames
# Processed 840 frames, saved 115 frames
# Processed 850 frames, saved 115 frames
# Processed 860 frames, saved 115 frames
# Processed 870 frames, saved 115 frames
# Processed 880 frames, saved 115 frames
# Processed 890 frames, saved 115 frames
# Processed 900 frames, saved 115 frames
# Processed 910 frames, saved 115 frames
# Processed 920 frames, saved 115 frames
# Processed 930 frames, saved 115 frames
# Processed 940 frames, saved 117 frames
# Processed 950 frames, saved 122 frames
# Processed 960 frames, saved 127 frames
# Processed 970 frames, saved 131 frames
# Processed 980 frames, saved 133 frames
# Processed 990 frames, saved 136 frames
# Processed 1000 frames, saved 140 frames
# Processed 1010 frames, saved 143 frames
# Processed 1020 frames, saved 146 frames
# Processed 1030 frames, saved 149 frames
# Processed 1040 frames, saved 153 frames
# Processed 1050 frames, saved 156 frames
# Processed 1060 frames, saved 160 frames
# Processed 1070 frames, saved 164 frames
# Processed 1080 frames, saved 164 frames
# Processed 1090 frames, saved 164 frames
# Processed 1100 frames, saved 164 frames
# Processed 1110 frames, saved 164 frames
# Processed 1120 frames, saved 164 frames
# Processed 1130 frames, saved 164 frames
# Processed 1140 frames, saved 164 frames
# Processed 1150 frames, saved 165 frames
# Processed 1160 frames, saved 167 frames
# Processed 1170 frames, saved 170 frames
# Processed 1180 frames, saved 175 frames
# Processed 1190 frames, saved 178 frames
# Processed 1200 frames, saved 181 frames
# Processed 1210 frames, saved 186 frames
# Processed 1220 frames, saved 189 frames
# Processed 1230 frames, saved 192 frames
# Processed 1240 frames, saved 196 frames
# Processed 1250 frames, saved 200 frames
# Processed 1260 frames, saved 204 frames
# Processed 1270 frames, saved 206 frames
# Processed 1280 frames, saved 208 frames
# Processed 1290 frames, saved 210 frames
# Processed 1300 frames, saved 210 frames
# Processed 1310 frames, saved 210 frames
# Processed 1320 frames, saved 210 frames
# Processed 1330 frames, saved 210 frames
# Processed 1340 frames, saved 210 frames
# Processed 1350 frames, saved 210 frames
# Processed 1360 frames, saved 210 frames
# Processed 1370 frames, saved 210 frames
# Processed 1380 frames, saved 210 frames
# Processed 1390 frames, saved 210 frames
# Processed 1400 frames, saved 210 frames
# Processed 1410 frames, saved 210 frames
# Processed 1420 frames, saved 210 frames
# Processed 1430 frames, saved 210 frames
# Processed 1440 frames, saved 213 frames
# Processed 1450 frames, saved 217 frames
# Processed 1460 frames, saved 220 frames
# Processed 1470 frames, saved 224 frames
# Processed 1480 frames, saved 228 frames
# Processed 1490 frames, saved 231 frames
# Processed 1500 frames, saved 234 frames
# Processed 1510 frames, saved 238 frames
# Processed 1520 frames, saved 242 frames
# Processed 1530 frames, saved 245 frames
# Processed 1540 frames, saved 248 frames
# Processed 1550 frames, saved 251 frames
# Processed 1560 frames, saved 254 frames
# Processed 1570 frames, saved 254 frames
# Processed 1580 frames, saved 254 frames
# Processed 1590 frames, saved 254 frames
# Processed 1600 frames, saved 254 frames
# Processed 1610 frames, saved 254 frames
# Processed 1620 frames, saved 254 frames
# Processed 1630 frames, saved 254 frames
# Processed 1640 frames, saved 256 frames
# Processed 1650 frames, saved 260 frames
# Processed 1660 frames, saved 265 frames
# Processed 1670 frames, saved 268 frames
# Processed 1680 frames, saved 271 frames
# Processed 1690 frames, saved 274 frames
# Processed 1700 frames, saved 278 frames
# Processed 1710 frames, saved 282 frames
# Processed 1720 frames, saved 285 frames
# Processed 1730 frames, saved 288 frames
# Processed 1740 frames, saved 293 frames
# Processed 1750 frames, saved 296 frames
# Processed 1760 frames, saved 299 frames
# Processed 1770 frames, saved 300 frames
# Processed 1780 frames, saved 300 frames
# Processed 1790 frames, saved 300 frames
# Processed 1800 frames, saved 300 frames
# Processed 1810 frames, saved 300 frames
# Processed 1820 frames, saved 300 frames
# Processed 1830 frames, saved 300 frames
# Processed 1840 frames, saved 300 frames
# Processed 1850 frames, saved 300 frames
# Processed 1860 frames, saved 300 frames
# Processed 1870 frames, saved 300 frames
# Processed 1880 frames, saved 300 frames
# Processed 1890 frames, saved 300 frames
# Processed 1900 frames, saved 304 frames
# Processed 1910 frames, saved 309 frames
# Processed 1920 frames, saved 312 frames
# Processed 1930 frames, saved 315 frames
# Processed 1940 frames, saved 319 frames
# Processed 1950 frames, saved 322 frames
# Processed 1960 frames, saved 325 frames
# Processed 1970 frames, saved 329 frames
# Processed 1980 frames, saved 333 frames
# Processed 1990 frames, saved 337 frames
# Processed 2000 frames, saved 341 frames
# Processed 2010 frames, saved 345 frames
# Processed 2020 frames, saved 347 frames
# Processed 2030 frames, saved 347 frames
# Processed 2040 frames, saved 347 frames
# Processed 2050 frames, saved 347 frames
# Processed 2060 frames, saved 347 frames
# Processed 2070 frames, saved 347 frames
# Processed 2080 frames, saved 347 frames
# Processed 2090 frames, saved 347 frames
# Processed 2100 frames, saved 348 frames
# Processed 2110 frames, saved 352 frames
# Processed 2120 frames, saved 356 frames
# Processed 2130 frames, saved 359 frames
# Processed 2140 frames, saved 363 frames
# Processed 2150 frames, saved 367 frames
# Processed 2160 frames, saved 370 frames
# Processed 2170 frames, saved 375 frames
# Processed 2180 frames, saved 378 frames
# Processed 2190 frames, saved 382 frames
# Processed 2200 frames, saved 386 frames
# Processed 2210 frames, saved 390 frames
# Processed 2220 frames, saved 394 frames
# Processed 2230 frames, saved 396 frames
# Processed 2240 frames, saved 396 frames
# Processed 2250 frames, saved 396 frames
# Processed 2260 frames, saved 396 frames
# Processed 2270 frames, saved 396 frames
# Processed 2280 frames, saved 396 frames
# Processed 2290 frames, saved 396 frames
# Processed 2300 frames, saved 396 frames
# Processed 2310 frames, saved 396 frames
# Processed 2320 frames, saved 396 frames
# Processed 2330 frames, saved 396 frames
# Processed 2340 frames, saved 396 frames
# Total silhouettes saved: 396
# Saved final silhouette image to /content/gait/Output/sub11/silhouette.png
# Processed /content/gait/sub11/ahmedh_m_1_front.MOV and saved results to /content/gait/Output/sub11
# Processed 10 frames, saved 4 frames
# Processed 20 frames, saved 9 frames
# Processed 30 frames, saved 11 frames
# Processed 40 frames, saved 15 frames
# Processed 50 frames, saved 18 frames
# Processed 60 frames, saved 18 frames
# Processed 70 frames, saved 20 frames
# Processed 80 frames, saved 22 frames
# Processed 90 frames, saved 24 frames
# Processed 100 frames, saved 28 frames
# Processed 110 frames, saved 30 frames
# Processed 120 frames, saved 30 frames
# Processed 130 frames, saved 30 frames
# Processed 140 frames, saved 30 frames
# Processed 150 frames, saved 30 frames
# Processed 160 frames, saved 30 frames
# Processed 170 frames, saved 30 frames
# Processed 180 frames, saved 30 frames
# Processed 190 frames, saved 30 frames
# Processed 200 frames, saved 30 frames
# Processed 210 frames, saved 30 frames
# Processed 220 frames, saved 30 frames
# Processed 230 frames, saved 30 frames
# Processed 240 frames, saved 30 frames
# Processed 250 frames, saved 30 frames
# Processed 260 frames, saved 32 frames
# Processed 270 frames, saved 37 frames
# Processed 280 frames, saved 41 frames
# Processed 290 frames, saved 46 frames
# Processed 300 frames, saved 49 frames
# Processed 310 frames, saved 52 frames
# Processed 320 frames, saved 57 frames
# Processed 330 frames, saved 61 frames
# Processed 340 frames, saved 64 frames
# Processed 350 frames, saved 68 frames
# Processed 360 frames, saved 72 frames
# Processed 370 frames, saved 76 frames
# Processed 380 frames, saved 80 frames
# Processed 390 frames, saved 80 frames
# Processed 400 frames, saved 80 frames
# Processed 410 frames, saved 80 frames
# Processed 420 frames, saved 80 frames
# Processed 430 frames, saved 82 frames
# Processed 440 frames, saved 85 frames
# Processed 450 frames, saved 89 frames
# Processed 460 frames, saved 93 frames
# Processed 470 frames, saved 96 frames
# Processed 480 frames, saved 100 frames
# Processed 490 frames, saved 104 frames
# Processed 500 frames, saved 109 frames
# Processed 510 frames, saved 113 frames
# Processed 520 frames, saved 116 frames
# Processed 530 frames, saved 121 frames
# Processed 540 frames, saved 125 frames
# Processed 550 frames, saved 129 frames
# Processed 560 frames, saved 132 frames
# Processed 570 frames, saved 132 frames
# Processed 580 frames, saved 132 frames
# Processed 590 frames, saved 132 frames
# Processed 600 frames, saved 132 frames
# Processed 610 frames, saved 132 frames
# Processed 620 frames, saved 132 frames
# Processed 630 frames, saved 132 frames
# Processed 640 frames, saved 132 frames
# Processed 650 frames, saved 132 frames
# Processed 660 frames, saved 132 frames
# Processed 670 frames, saved 132 frames
# Processed 680 frames, saved 132 frames
# Processed 690 frames, saved 132 frames
# Processed 700 frames, saved 132 frames
# Processed 710 frames, saved 132 frames
# Processed 720 frames, saved 136 frames
# Processed 730 frames, saved 140 frames
# Processed 740 frames, saved 144 frames
# Processed 750 frames, saved 148 frames
# Processed 760 frames, saved 152 frames
# Processed 770 frames, saved 156 frames
# Processed 780 frames, saved 160 frames
# Processed 790 frames, saved 164 frames
# Processed 800 frames, saved 168 frames
# Processed 810 frames, saved 173 frames
# Processed 820 frames, saved 177 frames
# Processed 830 frames, saved 181 frames
# Processed 840 frames, saved 184 frames
# Processed 850 frames, saved 184 frames
# Processed 860 frames, saved 184 frames
# Processed 870 frames, saved 184 frames
# Processed 880 frames, saved 184 frames
# Processed 890 frames, saved 184 frames
# Processed 900 frames, saved 184 frames
# Processed 910 frames, saved 184 frames
# Processed 920 frames, saved 187 frames
# Processed 930 frames, saved 191 frames
# Processed 940 frames, saved 195 frames
# Processed 950 frames, saved 198 frames
# Processed 960 frames, saved 202 frames
# Processed 970 frames, saved 206 frames
# Processed 980 frames, saved 210 frames
# Processed 990 frames, saved 213 frames
# Processed 1000 frames, saved 217 frames
# Processed 1010 frames, saved 222 frames
# Processed 1020 frames, saved 226 frames
# Processed 1030 frames, saved 229 frames
# Processed 1040 frames, saved 231 frames
# Processed 1050 frames, saved 231 frames
# Processed 1060 frames, saved 231 frames
# Processed 1070 frames, saved 231 frames
# Processed 1080 frames, saved 231 frames
# Processed 1090 frames, saved 231 frames
# Processed 1100 frames, saved 231 frames
# Processed 1110 frames, saved 231 frames
# Processed 1120 frames, saved 231 frames
# Processed 1130 frames, saved 231 frames
# Processed 1140 frames, saved 231 frames
# Processed 1150 frames, saved 231 frames
# Processed 1160 frames, saved 231 frames
# Processed 1170 frames, saved 231 frames
# Processed 1180 frames, saved 235 frames
# Processed 1190 frames, saved 239 frames
# Processed 1200 frames, saved 244 frames
# Processed 1210 frames, saved 248 frames
# Processed 1220 frames, saved 251 frames
# Processed 1230 frames, saved 255 frames
# Processed 1240 frames, saved 258 frames
# Processed 1250 frames, saved 262 frames
# Processed 1260 frames, saved 265 frames
# Processed 1270 frames, saved 270 frames
# Processed 1280 frames, saved 273 frames
# Processed 1290 frames, saved 278 frames
# Processed 1300 frames, saved 281 frames
# Processed 1310 frames, saved 283 frames
# Processed 1320 frames, saved 283 frames
# Processed 1330 frames, saved 283 frames
# Processed 1340 frames, saved 283 frames
# Processed 1350 frames, saved 283 frames
# Processed 1360 frames, saved 283 frames
# Processed 1370 frames, saved 283 frames
# Processed 1380 frames, saved 284 frames
# Processed 1390 frames, saved 288 frames
# Processed 1400 frames, saved 292 frames
# Processed 1410 frames, saved 295 frames
# Processed 1420 frames, saved 299 frames
# Processed 1430 frames, saved 303 frames
# Processed 1440 frames, saved 306 frames
# Processed 1450 frames, saved 310 frames
# Processed 1460 frames, saved 313 frames
# Processed 1470 frames, saved 317 frames
# Processed 1480 frames, saved 321 frames
# Processed 1490 frames, saved 326 frames
# Processed 1500 frames, saved 329 frames
# Processed 1510 frames, saved 333 frames
# Processed 1520 frames, saved 333 frames
# Processed 1530 frames, saved 333 frames
# Processed 1540 frames, saved 333 frames
# Processed 1550 frames, saved 333 frames
# Processed 1560 frames, saved 333 frames
# Processed 1570 frames, saved 333 frames
# Processed 1580 frames, saved 333 frames
# Processed 1590 frames, saved 333 frames
# Processed 1600 frames, saved 333 frames
# Processed 1610 frames, saved 333 frames
# Total silhouettes saved: 333
# Saved final silhouette image to /content/gait/Output/sub16/silhouette.png
# Processed /content/gait/sub16/youssefh_m_1_front.MOV and saved results to /content/gait/Output/sub16
# Processed 10 frames, saved 1 frames
# Processed 20 frames, saved 1 frames
# Processed 30 frames, saved 1 frames
# Processed 40 frames, saved 1 frames
# Processed 50 frames, saved 2 frames
# Processed 60 frames, saved 7 frames
# Processed 70 frames, saved 9 frames
# Processed 80 frames, saved 15 frames
# Processed 90 frames, saved 16 frames
# Processed 100 frames, saved 17 frames
# Processed 110 frames, saved 18 frames
# Processed 120 frames, saved 20 frames
# Processed 130 frames, saved 21 frames
# Processed 140 frames, saved 22 frames
# Processed 150 frames, saved 26 frames
# Processed 160 frames, saved 28 frames
# Processed 170 frames, saved 28 frames
# Processed 180 frames, saved 28 frames
# Processed 190 frames, saved 28 frames
# Processed 200 frames, saved 28 frames
# Processed 210 frames, saved 28 frames
# Processed 220 frames, saved 28 frames
# Processed 230 frames, saved 28 frames
# Processed 240 frames, saved 28 frames
# Processed 250 frames, saved 28 frames
# Processed 260 frames, saved 28 frames
# Processed 270 frames, saved 28 frames
# Processed 280 frames, saved 28 frames
# Processed 290 frames, saved 28 frames
# Processed 300 frames, saved 31 frames
# Processed 310 frames, saved 35 frames
# Processed 320 frames, saved 38 frames
# Processed 330 frames, saved 42 frames
# Processed 340 frames, saved 45 frames
# Processed 350 frames, saved 48 frames
# Processed 360 frames, saved 52 frames
# Processed 370 frames, saved 55 frames
# Processed 380 frames, saved 58 frames
# Processed 390 frames, saved 62 frames
# Processed 400 frames, saved 65 frames
# Processed 410 frames, saved 68 frames
# Processed 420 frames, saved 71 frames
# Processed 430 frames, saved 72 frames
# Processed 440 frames, saved 72 frames
# Processed 450 frames, saved 72 frames
# Processed 460 frames, saved 72 frames
# Processed 470 frames, saved 74 frames
# Processed 480 frames, saved 77 frames
# Processed 490 frames, saved 80 frames
# Processed 500 frames, saved 84 frames
# Processed 510 frames, saved 86 frames
# Processed 520 frames, saved 89 frames
# Processed 530 frames, saved 92 frames
# Processed 540 frames, saved 95 frames
# Processed 550 frames, saved 99 frames
# Processed 560 frames, saved 102 frames
# Processed 570 frames, saved 105 frames
# Processed 580 frames, saved 109 frames
# Processed 590 frames, saved 114 frames
# Processed 600 frames, saved 116 frames
# Processed 610 frames, saved 116 frames
# Processed 620 frames, saved 116 frames
# Processed 630 frames, saved 116 frames
# Processed 640 frames, saved 116 frames
# Processed 650 frames, saved 116 frames
# Processed 660 frames, saved 116 frames
# Processed 670 frames, saved 116 frames
# Processed 680 frames, saved 116 frames
# Processed 690 frames, saved 116 frames
# Processed 700 frames, saved 116 frames
# Processed 710 frames, saved 116 frames
# Processed 720 frames, saved 119 frames
# Processed 730 frames, saved 123 frames
# Processed 740 frames, saved 125 frames
# Processed 750 frames, saved 129 frames
# Processed 760 frames, saved 132 frames
# Processed 770 frames, saved 134 frames
# Processed 780 frames, saved 138 frames
# Processed 790 frames, saved 141 frames
# Processed 800 frames, saved 144 frames
# Processed 810 frames, saved 147 frames
# Processed 820 frames, saved 150 frames
# Processed 830 frames, saved 152 frames
# Processed 840 frames, saved 155 frames
# Processed 850 frames, saved 157 frames
# Processed 860 frames, saved 157 frames
# Processed 870 frames, saved 157 frames
# Processed 880 frames, saved 157 frames
# Processed 890 frames, saved 158 frames
# Processed 900 frames, saved 162 frames
# Processed 910 frames, saved 165 frames
# Processed 920 frames, saved 169 frames
# Processed 930 frames, saved 171 frames
# Processed 940 frames, saved 175 frames
# Processed 950 frames, saved 179 frames
# Processed 960 frames, saved 183 frames
# Processed 970 frames, saved 186 frames
# Processed 980 frames, saved 190 frames
# Processed 990 frames, saved 195 frames
# Processed 1000 frames, saved 198 frames
# Processed 1010 frames, saved 202 frames
# Processed 1020 frames, saved 205 frames
# Processed 1030 frames, saved 206 frames
# Processed 1040 frames, saved 206 frames
# Processed 1050 frames, saved 206 frames
# Processed 1060 frames, saved 206 frames
# Processed 1070 frames, saved 206 frames
# Processed 1080 frames, saved 206 frames
# Processed 1090 frames, saved 206 frames
# Processed 1100 frames, saved 206 frames
# Processed 1110 frames, saved 206 frames
# Processed 1120 frames, saved 206 frames
# Processed 1130 frames, saved 212 frames
# Processed 1140 frames, saved 215 frames
# Processed 1150 frames, saved 218 frames
# Processed 1160 frames, saved 221 frames
# Processed 1170 frames, saved 225 frames
# Processed 1180 frames, saved 228 frames
# Processed 1190 frames, saved 231 frames
# Processed 1200 frames, saved 234 frames
# Processed 1210 frames, saved 237 frames
# Processed 1220 frames, saved 240 frames
# Processed 1230 frames, saved 243 frames
# Processed 1240 frames, saved 245 frames
# Processed 1250 frames, saved 248 frames
# Processed 1260 frames, saved 251 frames
# Processed 1270 frames, saved 251 frames
# Processed 1280 frames, saved 251 frames
# Processed 1290 frames, saved 251 frames
# Processed 1300 frames, saved 251 frames
# Processed 1310 frames, saved 252 frames
# Processed 1320 frames, saved 254 frames
# Processed 1330 frames, saved 257 frames
# Processed 1340 frames, saved 261 frames
# Processed 1350 frames, saved 264 frames
# Processed 1360 frames, saved 269 frames
# Processed 1370 frames, saved 272 frames
# Processed 1380 frames, saved 276 frames
# Processed 1390 frames, saved 279 frames
# Processed 1400 frames, saved 283 frames
# Processed 1410 frames, saved 288 frames
# Processed 1420 frames, saved 291 frames
# Processed 1430 frames, saved 296 frames
# Processed 1440 frames, saved 301 frames
# Processed 1450 frames, saved 301 frames
# Processed 1460 frames, saved 301 frames
# Processed 1470 frames, saved 301 frames
# Processed 1480 frames, saved 301 frames
# Processed 1490 frames, saved 301 frames
# Processed 1500 frames, saved 301 frames
# Processed 1510 frames, saved 301 frames
# Total silhouettes saved: 301
# Saved final silhouette image to /content/gait/Output/sub20/silhouette.png
# Processed /content/gait/sub20/rewany_f_1_front.MOV and saved results to /content/gait/Output/sub20
# Total silhouettes saved: 0
# No silhouettes to save
# Processed /content/gait/sub18/amir_m_1_front.MOV and saved results to /content/gait/Output/sub18
# Processed 10 frames, saved 1 frames
# Processed 20 frames, saved 1 frames
# Processed 30 frames, saved 1 frames
# Processed 40 frames, saved 1 frames
# Processed 50 frames, saved 1 frames
# Processed 60 frames, saved 1 frames
# Processed 70 frames, saved 1 frames
# Processed 80 frames, saved 1 frames
# Processed 90 frames, saved 6 frames
# Processed 100 frames, saved 12 frames
# Processed 110 frames, saved 17 frames
# Processed 120 frames, saved 18 frames
# Processed 130 frames, saved 18 frames
# Processed 140 frames, saved 19 frames
# Processed 150 frames, saved 22 frames
# Processed 160 frames, saved 23 frames
# Processed 170 frames, saved 24 frames
# Processed 180 frames, saved 24 frames
# Processed 190 frames, saved 25 frames
# ...
# Processed 1370 frames, saved 308 frames
# Processed 1380 frames, saved 313 frames
# Processed 1390 frames, saved 314 frames
# Processed 1400 frames, saved 316 frames
# Processed 1410 frames, saved 316 frames
# Processed 1420 frames, saved 316 frames
# Processed 1430 frames, saved 316 frames
# Processed 1440 frames, saved 316 frames
# Processed 1450 frames, saved 316 frames
# Processed 1460 frames, saved 316 frames
# Processed 1470 frames, saved 316 frames
# Processed 1480 frames, saved 316 frames
# Processed 1490 frames, saved 316 frames
# Total silhouettes saved: 316
# Saved final silhouette image to /content/gait/Output/sub3/silhouette.png
# Processed /content/gait/sub3/hydra_m_1_front.MOV and saved results to /content/gait/Output/sub3
# Processed 10 frames, saved 1 frames
# Processed 20 frames, saved 1 frames
# Processed 30 frames, saved 2 frames
# Processed 40 frames, saved 2 frames
# Processed 50 frames, saved 2 frames
# Processed 60 frames, saved 2 frames
# Processed 70 frames, saved 2 frames
# Processed 80 frames, saved 2 frames
# Processed 90 frames, saved 5 frames
# Processed 100 frames, saved 11 frames
# Processed 110 frames, saved 14 frames
# Processed 120 frames, saved 19 frames
# Processed 130 frames, saved 21 frames
# Processed 140 frames, saved 22 frames
# Processed 150 frames, saved 24 frames
# Processed 160 frames, saved 27 frames
# Processed 170 frames, saved 29 frames
# Processed 180 frames, saved 32 frames
# Processed 190 frames, saved 32 frames
# Processed 200 frames, saved 32 frames
# Processed 210 frames, saved 32 frames
# Total silhouettes saved: 32
# Saved final silhouette image to /content/gait/Output/sub4/silhouette.png
# Processed /content/gait/sub4/omar_m_1_front.MOV and saved results to /content/gait/Output/sub4
# Total silhouettes saved: 0
# No silhouettes to save
# Processed /content/gait/sub31/mohamedsh_m_1_front.MOV and saved results to /content/gait/Output/sub31
# Total silhouettes saved: 0
# No silhouettes to save
# Processed /content/gait/sub38/ahmedhat_m_1_front.MOV and saved results to /content/gait/Output/sub38
# Total silhouettes saved: 0
# No silhouettes to save
# Processed /content/gait/sub39/mustafaaa_m_1_front.MOV and saved results to /content/gait/Output/sub39
# Processed 10 frames, saved 1 frames
# Processed 20 frames, saved 1 frames
# Processed 30 frames, saved 1 frames
# Processed 40 frames, saved 1 frames
# Processed 50 frames, saved 1 frames
# Processed 60 frames, saved 1 frames
# Processed 70 frames, saved 1 frames
# Processed 80 frames, saved 1 frames
# Processed 90 frames, saved 1 frames
# Processed 100 frames, saved 1 frames
# Processed 110 frames, saved 1 frames
# Processed 120 frames, saved 1 frames
# Processed 130 frames, saved 1 frames
# Processed 140 frames, saved 1 frames
# Processed 150 frames, saved 1 frames
# Processed 160 frames, saved 1 frames
# Processed 170 frames, saved 1 frames
# Processed 180 frames, saved 1 frames
# Processed 190 frames, saved 1 frames
# Processed 200 frames, saved 1 frames
# Processed 210 frames, saved 1 frames
# Processed 220 frames, saved 1 frames
# Processed 230 frames, saved 1 frames
# Processed 240 frames, saved 1 frames
# Processed 250 frames, saved 1 frames
# Processed 260 frames, saved 1 frames
# Processed 270 frames, saved 1 frames
# Processed 280 frames, saved 5 frames
# Processed 290 frames, saved 9 frames
# Processed 300 frames, saved 15 frames
# Processed 310 frames, saved 18 frames
# Processed 320 frames, saved 19 frames
# Processed 330 frames, saved 22 frames
# Processed 340 frames, saved 24 frames
# Processed 350 frames, saved 24 frames
# Processed 360 frames, saved 24 frames
# Processed 370 frames, saved 24 frames
# Processed 380 frames, saved 24 frames
# Processed 390 frames, saved 24 frames
# Processed 400 frames, saved 24 frames
# Processed 410 frames, saved 24 frames
# Processed 420 frames, saved 24 frames
# Processed 430 frames, saved 24 frames
# Processed 440 frames, saved 24 frames
# Processed 450 frames, saved 24 frames
# Processed 460 frames, saved 24 frames
# Processed 470 frames, saved 25 frames
# Processed 480 frames, saved 28 frames
# Processed 490 frames, saved 30 frames
# Processed 500 frames, saved 33 frames
# Processed 510 frames, saved 38 frames
# Processed 520 frames, saved 40 frames
# Processed 530 frames, saved 43 frames
# Processed 540 frames, saved 47 frames
# Processed 550 frames, saved 51 frames
# Processed 560 frames, saved 54 frames
# Processed 570 frames, saved 58 frames
# Processed 580 frames, saved 61 frames
# Processed 590 frames, saved 65 frames
# Processed 600 frames, saved 68 frames
# Processed 610 frames, saved 70 frames
# Processed 620 frames, saved 70 frames
# Processed 630 frames, saved 70 frames
# Processed 640 frames, saved 70 frames
# Processed 650 frames, saved 70 frames
# Processed 660 frames, saved 70 frames
# Processed 670 frames, saved 71 frames
# Processed 680 frames, saved 75 frames
# Processed 690 frames, saved 78 frames
# Processed 700 frames, saved 81 frames
# Processed 710 frames, saved 85 frames
# Processed 720 frames, saved 88 frames
# Processed 730 frames, saved 93 frames
# Processed 740 frames, saved 97 frames
# Processed 750 frames, saved 101 frames
# Processed 760 frames, saved 105 frames
# Processed 770 frames, saved 108 frames
# Processed 780 frames, saved 112 frames
# Processed 790 frames, saved 115 frames
# Processed 800 frames, saved 116 frames
# Processed 810 frames, saved 116 frames
# Processed 820 frames, saved 116 frames
# Processed 830 frames, saved 116 frames
# Processed 840 frames, saved 116 frames
# Processed 850 frames, saved 116 frames
# Processed 860 frames, saved 116 frames
# Processed 870 frames, saved 116 frames
# Processed 880 frames, saved 116 frames
# Processed 890 frames, saved 116 frames
# Processed 900 frames, saved 116 frames
# Processed 910 frames, saved 116 frames
# Processed 920 frames, saved 116 frames
# Processed 930 frames, saved 119 frames
# Processed 940 frames, saved 122 frames
# Processed 950 frames, saved 125 frames
# Processed 960 frames, saved 129 frames
# Processed 970 frames, saved 133 frames
# Processed 980 frames, saved 136 frames
# Processed 990 frames, saved 140 frames
# Processed 1000 frames, saved 144 frames
# Processed 1010 frames, saved 147 frames
# Processed 1020 frames, saved 150 frames
# Processed 1030 frames, saved 153 frames
# Processed 1040 frames, saved 158 frames
# Processed 1050 frames, saved 161 frames
# Processed 1060 frames, saved 164 frames
# Processed 1070 frames, saved 165 frames
# Processed 1080 frames, saved 165 frames
# Processed 1090 frames, saved 165 frames
# Processed 1100 frames, saved 165 frames
# Processed 1110 frames, saved 166 frames
# Processed 1120 frames, saved 169 frames
# Processed 1130 frames, saved 172 frames
# Processed 1140 frames, saved 176 frames
# Processed 1150 frames, saved 179 frames
# Processed 1160 frames, saved 183 frames
# Processed 1170 frames, saved 187 frames
# Processed 1180 frames, saved 192 frames
# Processed 1190 frames, saved 196 frames
# Processed 1200 frames, saved 200 frames
# Processed 1210 frames, saved 204 frames
# Processed 1220 frames, saved 208 frames
# Processed 1230 frames, saved 212 frames
# Processed 1240 frames, saved 214 frames
# Processed 1250 frames, saved 215 frames
# Processed 1260 frames, saved 215 frames
# Processed 1270 frames, saved 215 frames
# Processed 1280 frames, saved 215 frames
# Processed 1290 frames, saved 215 frames
# Processed 1300 frames, saved 215 frames
# Processed 1310 frames, saved 215 frames
# Processed 1320 frames, saved 215 frames
# Processed 1330 frames, saved 215 frames
# Processed 1340 frames, saved 215 frames
# Processed 1350 frames, saved 215 frames
# Processed 1360 frames, saved 215 frames
# Processed 1370 frames, saved 219 frames
# Processed 1380 frames, saved 222 frames
# Processed 1390 frames, saved 226 frames
# Processed 1400 frames, saved 228 frames
# Processed 1410 frames, saved 232 frames
# Processed 1420 frames, saved 235 frames
# Processed 1430 frames, saved 238 frames
# Processed 1440 frames, saved 241 frames
# Processed 1450 frames, saved 244 frames
# Processed 1460 frames, saved 247 frames
# Processed 1470 frames, saved 251 frames
# Processed 1480 frames, saved 255 frames
# Processed 1490 frames, saved 258 frames
# Processed 1500 frames, saved 262 frames
# Processed 1510 frames, saved 263 frames
# Processed 1520 frames, saved 263 frames
# Processed 1530 frames, saved 263 frames
# Processed 1540 frames, saved 263 frames
# Processed 1550 frames, saved 263 frames
# Processed 1560 frames, saved 264 frames
# Processed 1570 frames, saved 266 frames
# Processed 1580 frames, saved 270 frames
# Processed 1590 frames, saved 273 frames
# Processed 1600 frames, saved 276 frames
# Processed 1610 frames, saved 280 frames
# Processed 1620 frames, saved 285 frames
# Processed 1630 frames, saved 288 frames
# Processed 1640 frames, saved 291 frames
# Processed 1650 frames, saved 296 frames
# Processed 1660 frames, saved 300 frames
# Processed 1670 frames, saved 303 frames
# Processed 1680 frames, saved 308 frames
# Processed 1690 frames, saved 312 frames
# Processed 1700 frames, saved 312 frames
# Processed 1710 frames, saved 312 frames
# Processed 1720 frames, saved 312 frames
# Processed 1730 frames, saved 312 frames
# Processed 1740 frames, saved 312 frames
# Processed 1750 frames, saved 312 frames
# Processed 1760 frames, saved 312 frames
# Processed 1770 frames, saved 312 frames
# Processed 1780 frames, saved 312 frames
# Processed 1790 frames, saved 312 frames
# Processed 1800 frames, saved 312 frames
# Total silhouettes saved: 312
# Saved final silhouette image to /content/gait/Output/sub30/silhouette.png
# Processed /content/gait/sub30/kahmedk_m_1_front.MOV and saved results to /content/gait/Output/sub30
# Processed 10 frames, saved 1 frames
# Processed 20 frames, saved 1 frames
# Processed 30 frames, saved 1 frames
# Processed 40 frames, saved 1 frames
# Processed 50 frames, saved 1 frames
# Processed 60 frames, saved 1 frames
# Processed 70 frames, saved 8 frames
# Processed 80 frames, saved 10 frames
# Processed 90 frames, saved 15 frames
# Processed 100 frames, saved 16 frames
# Processed 110 frames, saved 16 frames
# Processed 120 frames, saved 17 frames
# Processed 130 frames, saved 20 frames
# Processed 140 frames, saved 23 frames
# Processed 150 frames, saved 23 frames
# Processed 160 frames, saved 23 frames
# Processed 170 frames, saved 23 frames
# Processed 180 frames, saved 23 frames
# Processed 190 frames, saved 23 frames
# Processed 200 frames, saved 23 frames
# Processed 210 frames, saved 23 frames
# Processed 220 frames, saved 23 frames
# Processed 230 frames, saved 23 frames
# Processed 240 frames, saved 23 frames
# Processed 250 frames, saved 23 frames
# Processed 260 frames, saved 23 frames
# Processed 270 frames, saved 27 frames
# Processed 280 frames, saved 32 frames
# Processed 290 frames, saved 35 frames
# Processed 300 frames, saved 38 frames
# Processed 310 frames, saved 42 frames
# Processed 320 frames, saved 45 frames
# Processed 330 frames, saved 49 frames
# Processed 340 frames, saved 53 frames
# Processed 350 frames, saved 56 frames
# Processed 360 frames, saved 60 frames
# Processed 370 frames, saved 63 frames
# Processed 380 frames, saved 66 frames
# Processed 390 frames, saved 70 frames
# Processed 400 frames, saved 71 frames
# Processed 410 frames, saved 71 frames
# Processed 420 frames, saved 71 frames
# Processed 430 frames, saved 71 frames
# Processed 440 frames, saved 71 frames
# Processed 450 frames, saved 71 frames
# Processed 460 frames, saved 71 frames
# Processed 470 frames, saved 71 frames
# Processed 480 frames, saved 74 frames
# Processed 490 frames, saved 76 frames
# Processed 500 frames, saved 80 frames
# Processed 510 frames, saved 84 frames
# Processed 520 frames, saved 87 frames
# Processed 530 frames, saved 91 frames
# Processed 540 frames, saved 94 frames
# Processed 550 frames, saved 98 frames
# Processed 560 frames, saved 101 frames
# Processed 570 frames, saved 105 frames
# Processed 580 frames, saved 109 frames
# Processed 590 frames, saved 112 frames
# Processed 600 frames, saved 116 frames
# Processed 610 frames, saved 118 frames
# Processed 620 frames, saved 118 frames
# Processed 630 frames, saved 118 frames
# Processed 640 frames, saved 118 frames
# Processed 650 frames, saved 118 frames
# Processed 660 frames, saved 118 frames
# Processed 670 frames, saved 118 frames
# Processed 680 frames, saved 118 frames
# Processed 690 frames, saved 118 frames
# Processed 700 frames, saved 118 frames
# Processed 710 frames, saved 118 frames
# Processed 720 frames, saved 118 frames
# Processed 730 frames, saved 123 frames
# Processed 740 frames, saved 124 frames
# Processed 750 frames, saved 127 frames
# Processed 760 frames, saved 130 frames
# Processed 770 frames, saved 134 frames
# Processed 780 frames, saved 138 frames
# Processed 790 frames, saved 141 frames
# Processed 800 frames, saved 145 frames
# Processed 810 frames, saved 148 frames
# Processed 820 frames, saved 152 frames
# Processed 830 frames, saved 154 frames
# Processed 840 frames, saved 157 frames
# Processed 850 frames, saved 161 frames
# Processed 860 frames, saved 164 frames
# Processed 870 frames, saved 166 frames
# Processed 880 frames, saved 166 frames
# Processed 890 frames, saved 166 frames
# Processed 900 frames, saved 166 frames
# Processed 910 frames, saved 166 frames
# Processed 920 frames, saved 166 frames
# Processed 930 frames, saved 166 frames
# Processed 940 frames, saved 166 frames
# Processed 950 frames, saved 167 frames
# Processed 960 frames, saved 169 frames
# Processed 970 frames, saved 173 frames
# Processed 980 frames, saved 176 frames
# Processed 990 frames, saved 178 frames
# Processed 1000 frames, saved 181 frames
# Processed 1010 frames, saved 184 frames
# Processed 1020 frames, saved 187 frames
# Processed 1030 frames, saved 189 frames
# Processed 1040 frames, saved 193 frames
# Processed 1050 frames, saved 196 frames
# Processed 1060 frames, saved 200 frames
# Processed 1070 frames, saved 202 frames
# Processed 1080 frames, saved 205 frames
# Processed 1090 frames, saved 208 frames
# Processed 1100 frames, saved 210 frames
# Processed 1110 frames, saved 211 frames
# Processed 1120 frames, saved 211 frames
# Processed 1130 frames, saved 211 frames
# Processed 1140 frames, saved 211 frames
# Processed 1150 frames, saved 211 frames
# Processed 1160 frames, saved 211 frames
# Processed 1170 frames, saved 211 frames
# Processed 1180 frames, saved 211 frames
# Processed 1190 frames, saved 211 frames
# Processed 1200 frames, saved 211 frames
# Processed 1210 frames, saved 211 frames
# Processed 1220 frames, saved 214 frames
# Processed 1230 frames, saved 217 frames
# Processed 1240 frames, saved 221 frames
# Processed 1250 frames, saved 224 frames
# Processed 1260 frames, saved 227 frames
# Processed 1270 frames, saved 231 frames
# Processed 1280 frames, saved 235 frames
# Processed 1290 frames, saved 239 frames
# Processed 1300 frames, saved 241 frames
# Processed 1310 frames, saved 245 frames
# Processed 1320 frames, saved 248 frames
# Processed 1330 frames, saved 251 frames
# Processed 1340 frames, saved 254 frames
# Processed 1350 frames, saved 257 frames
# Processed 1360 frames, saved 258 frames
# Processed 1370 frames, saved 258 frames
# Processed 1380 frames, saved 258 frames
# Processed 1390 frames, saved 258 frames
# Processed 1400 frames, saved 258 frames
# Processed 1410 frames, saved 258 frames
# Processed 1420 frames, saved 258 frames
# Processed 1430 frames, saved 258 frames
# Processed 1440 frames, saved 258 frames
# Processed 1450 frames, saved 258 frames
# Processed 1460 frames, saved 261 frames
# Processed 1470 frames, saved 264 frames
# Processed 1480 frames, saved 266 frames
# Processed 1490 frames, saved 270 frames
# Processed 1500 frames, saved 273 frames
# Processed 1510 frames, saved 277 frames
# Processed 1520 frames, saved 279 frames
# Processed 1530 frames, saved 283 frames
# Processed 1540 frames, saved 287 frames
# Processed 1550 frames, saved 290 frames
# Processed 1560 frames, saved 292 frames
# Processed 1570 frames, saved 295 frames
# Processed 1580 frames, saved 299 frames
# Processed 1590 frames, saved 301 frames
# Processed 1600 frames, saved 302 frames
# Processed 1610 frames, saved 302 frames
# Processed 1620 frames, saved 302 frames
# Processed 1630 frames, saved 302 frames
# Processed 1640 frames, saved 302 frames
# Processed 1650 frames, saved 302 frames
# Total silhouettes saved: 302
# Saved final silhouette image to /content/gait/Output/sub37/silhouette.png
# Processed /content/gait/sub37/menaos_f_1_front.MOV and saved results to /content/gait/Output/sub37
